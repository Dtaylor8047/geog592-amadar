# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %%
filename = "finalized.csv"

df = pd.read_csv(filename, encoding="ISO-8859-1")

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.head()
# Out:
#                             Title  Release Year  \
# 0                 Chance Season 2        2017.0
# 1                       Red Widow        2013.0
# 2  A Taiwanese Tale of Two Cities        2018.0
# 3                       Americana        2015.0
# 4                            DEVS        2020.0
#
#                            Distributor                 Production   Longitude  \
# 0                                 Hulu       TVM Productions Inc. -122.405822
# 1  American Broadcasting Company (ABC)                 Beyond Pix -122.411031
# 2                              Netflix  Envision Productions Inc. -122.396034
# 3                                  NaN            Sutro Films LLC -122.448423
# 4                           FX Network          Minim Productions -122.417619
#
#     Latitude
# 0  37.802395
# 1  37.792781
# 2  37.798070
# 3  37.802931
# 4  37.800359

# %%
df.shape
# Out:
# (2127, 6)

# %%
df.tail()
# Out:
#                         Title  Release Year  \
# 2122            Nora Prentiss        1947.0
# 2123     Ant-Man and the Wasp        2018.0
# 2124                    Venom        2018.0
# 2125  Looking Season 2 ep 206        2015.0
# 2126              Dope Queens        2025.0
#
#                                      Distributor  \
# 2122                       Warner Bros. Pictures
# 2123         Walt Disney Studios Motion Pictures
# 2124  Columbia Pictures, Sony Pictures Releasing
# 2125                                         HBO
# 2126                                         TBD
#
#                              Production   Longitude   Latitude
# 2122              Warner Bros. Pictures -122.413322  37.788455
# 2123  PYM Particles Productions II, LLC -122.414910  37.795960
# 2124           L.O.Z. Productions, Inc. -122.410246  37.800775
# 2125    Mission Street Productions, LLC -122.434890  37.771831
# 2126   TomorrowLand Productions Co Inc. -122.416134  37.752482

# %%
df.dtypes
# Out:
# Title               str
# Release Year    float64
# Distributor         str
# Production          str
# Longitude       float64
# Latitude        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Title', 'Release Year', 'Distributor', 'Production', 'Longitude',
#        'Latitude'],
#       dtype='str')

# %%
df.info
# Out:
# <bound method DataFrame.info of                                Title  Release Year  \
# 0                    Chance Season 2        2017.0
# 1                          Red Widow        2013.0
# 2     A Taiwanese Tale of Two Cities        2018.0
# 3                          Americana        2015.0
# 4                               DEVS        2020.0
# ...                              ...           ...
# 2122                   Nora Prentiss        1947.0
# 2123            Ant-Man and the Wasp        2018.0
# 2124                           Venom        2018.0
# 2125         Looking Season 2 ep 206        2015.0
# 2126                     Dope Queens        2025.0
#
#                                      Distributor  \
# 0                                           Hulu
# 1            American Broadcasting Company (ABC)
# 2                                        Netflix
# 3                                            NaN
# 4                                     FX Network
# ...

# %%
mask = df["Title"].str.startswith("T", na=False)

df2 = df[mask]
df2
# Out:
#                      Title  Release Year                         Distributor  \
# 8      The Wedding Planner        2001.0         Sony Pictures Entertainment
# 10         Time After Time        1979.0  Columbia Broadcasting System (CBS)
# 11    Terminator - Genisys        2015.0                  Paramount Pictures
# 38            The Presidio        1988.0                  Paramount Pictures
# 43    Terminator - Genisys        2015.0                  Paramount Pictures
# ...                    ...           ...                                 ...
# 2087         The Dead Pool        1988.0               Warner Bros. Pictures
# 2094        The OA Part II        2019.0                             Netflix
# 2099         The Dead Pool        1988.0               Warner Bros. Pictures
# 2115          The Love Bug        1968.0            Buena Vista Distribution
# 2119          The Enforcer        1976.0               Warner Bros. Pictures
#
# ...
