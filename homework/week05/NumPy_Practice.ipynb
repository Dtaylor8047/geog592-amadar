# %%
locations = ["Oak", "Pine", "Maple", "Cedar", "Elm"]

# %% [markdown]
# 1. Oak
# 2. Elm
# 3. Pine, Maple, Cedar
# 4. locations[2]

# %%
points = [[100, 200], [140, 230], [180, 260], [120, 280]]

# %% [markdown]
# 5. [180, 260]
# 6. 260; The first number selects the lists within points and the second number selects the first or second value within list inside points.
# 7. points[1][0]

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Oak", "Pine", "Maple", "Cedar"],
    "ft": [25, 48, 31, 60],
    "zone": ["A", "B", "A", "B"]
})

# %% [markdown]
# 8. Series object
# 9. df[["name", "ft"]]
# 10. Pine, 48, B
# 11. df.iloc[:3]
# 12. df[df["ft"] > 30]
# 13. Pine, 48, B; Maple, 31, A

# %%
import numpy as np

points = np.array([
    [100, 200],
    [140, 230],
    [180, 260],
    [120, 280]
])

# %% [markdown]
# 14. (4, 2); 4 rows and 2 columns
# 15. [100, 200]
# 16. 200
# 17. 100, 140, 180, 120; All values in first column
# 18. 200, 230, 260, 280
# 19. points[1:3, :]
# 20. The values are the same

# %%
shift = np.array([10, 20])

# %% [markdown]
# 21. The result would add 10 to the values in the first column and 20 to the ones in the second column.
# 22. Numpy allows vectorization to occur without a for loop

# %%
x = points[:, 0]
y = points[:, 1]

inside = (x >= 110) & (x <= 150) & (y >= 220) & (y <= 290)

# %% [markdown]
# 23. False, True, False, True
# 24. It will return the values in points that are true for inside
# 25. Clip

# %%
elevation = np.array([240, 510, 430, 680])
classes = np.where(elevation >= 500, 1, 0)

# %% [markdown]
# 26. 0, 1, 0, 1
# 27. Condition is used to identify certain values, value_if_true is the value given to the values that satisfy the condition, value_if_false is the value given to the values that don't

# %%
a = np.array([100, 200])
b = np.array([140, 230])

distance = np.sqrt(((a - b) ** 2).sum())

# %% [markdown]
# 28. The differences of the values in array a minus array b
# 29. The math used iterates through multiple rows

# %%
ft_array = df["ft"].to_numpy()

# %% [markdown]
# 30. Array
# 31. They were not included on the array

# %% [markdown]
# 32.
# a. Maple
# b. 260
# c. Third row, Second item
# d. 260
# e. 100, 140, 180, 120

# %% [markdown]
# 33. You are able to access data by column and row
# 34. Identifying the particular row and column a data point is at
